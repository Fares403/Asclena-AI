# %%
import pandas as pd
df = pd.read_csv('/home/fares-ashraf/snap/dbeaver-ce/471/patient_feature_store_202604282324.csv')

# %%
df.head()
# Out:
#     stay_id  subject_id  gender  gender_male  gender_female  gender_unknown  \
# 0  30000012    11714491  Female            0              1               0
# 1  30000017    14230614    Male            1              0               0
# 2  30000038    13821532  Female            0              1               0
# 3  30000039    13340997    Male            1              0               0
# 4  30000055    19848164  Female            0              1               0
#
#                      race arrival_transport disposition  has_hadm_id  ...  \
# 0                   WHITE         AMBULANCE    ADMITTED            1  ...
# 1  BLACK/AFRICAN AMERICAN           WALK IN      ELOPED            0  ...
# 2                   WHITE         AMBULANCE    ADMITTED            1  ...
# 3                   WHITE           WALK IN    ADMITTED            1  ...
# 4                   OTHER           WALK IN        HOME            0  ...
#
#    pyxis_distinct_med_count  pyxis_distinct_gsn_count  \
# 0                         3                         2
# 1                         3                         6
# 2                         2                         0
# 3                         2                         3
# 4                         0                         0
#
#    pyxis_missing_gsn_count  med_recon_count  med_recon_distinct_med_count  \
# 0                        1               13                             8
# 1                        0                0                             0
# 2                        2               11                            10
# 3                        0                2                             2
# 4                        0                1                             1
#
#    med_recon_distinct_ndc_count  med_recon_missing_etccode_count  \
# 0                             9                                0
# 1                             0                                0
# 2                            10                                0
# 3                             2                                0
# 4                             1                                0
#
#    medication_intensity_score  risk_target                     updated_at
# 0                          16            1  2026-04-28 23:17:54.396 +0300
# 1                           6            0  2026-04-28 23:17:54.396 +0300
# 2                          13            1  2026-04-28 23:17:54.396 +0300
# 3                           5            1  2026-04-28 23:17:54.396 +0300
# 4                           1            0  2026-04-28 23:17:54.396 +0300
#
# [5 rows x 92 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 425087 entries, 0 to 425086
# Data columns (total 92 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   stay_id                          425087 non-null  int64
#  1   subject_id                       425087 non-null  int64
#  2   gender                           425087 non-null  str
#  3   gender_male                      425087 non-null  int64
#  4   gender_female                    425087 non-null  int64
#  5   gender_unknown                   425087 non-null  int64
#  6   race                             425087 non-null  str
#  7   arrival_transport                425087 non-null  str
#  8   disposition                      425087 non-null  str
#  9   has_hadm_id                      425087 non-null  int64
#  10  length_of_stay_hours             425087 non-null  float64
#  11  triage_temperature               401055 non-null  float64
#  12  triage_heartrate                 407957 non-null  float64
#  13  triage_resprate                  404674 non-null  float64
#  14  triage_o2sat                     404399 non-null  float64
#  15  triage_sbp                       406796 non-null  float64
#  16  triage_dbp                       405996 non-null  float64
#  17  acuity                           418100 non-null  float64
#  18  triage_temperature_missing       425087 non-null  int64
#  19  triage_heartrate_missing         425087 non-null  int64
#  20  triage_resprate_missing          425087 non-null  int64
#  21  triage_o2sat_missing             425087 non-null  int64
#  22  triage_sbp_missing               425087 non-null  int64
#  23  triage_dbp_missing               425087 non-null  int64
#  24  acuity_missing                   425087 non-null  int64
#  25  triage_pain_unknown              425087 non-null  int64
#  26  chiefcomplaint_unknown           425087 non-null  int64
#  27  triage_shock_index               405957 non-null  float64
#  28  vital_row_count                  425087 non-null  int64
#  29  temperature_count                425087 non-null  int64
#  30  heartrate_count                  425087 non-null  int64
#  31  resprate_count                   425087 non-null  int64
#  32  o2sat_count                      425087 non-null  int64
#  33  sbp_count                        425087 non-null  int64
#  34  dbp_count                        425087 non-null  int64
#  35  temperature_mean                 398614 non-null  float64
#  36  temperature_min                  398614 non-null  float64
#  37  temperature_max                  398614 non-null  float64
#  38  hr_mean                          406600 non-null  float64
#  39  hr_min                           406600 non-null  float64
#  40  hr_max                           406600 non-null  float64
#  41  rr_mean                          406127 non-null  float64
#  42  rr_min                           406127 non-null  float64
#  43  rr_max                           406127 non-null  float64
#  44  spo2_mean                        395923 non-null  float64
#  45  spo2_min                         395923 non-null  float64
#  46  spo2_max                         395923 non-null  float64
#  47  sbp_mean                         406271 non-null  float64
#  48  sbp_min                          406271 non-null  float64
#  49  sbp_max                          406271 non-null  float64
#  50  dbp_mean                         406359 non-null  float64
#  51  dbp_min                          406359 non-null  float64
#  52  dbp_max                          406359 non-null  float64
#  53  shock_index                      406046 non-null  float64
#  54  shock_index_max                  406046 non-null  float64
#  55  hr_first                         406600 non-null  float64
#  56  hr_last                          406600 non-null  float64
#  57  hr_slope                         326897 non-null  float64
#  58  sbp_first                        406271 non-null  float64
#  59  sbp_last                         406271 non-null  float64
#  60  bp_slope                         325747 non-null  float64
#  61  temperature_missing_rate         406921 non-null  float64
#  62  heartrate_missing_rate           406921 non-null  float64
#  63  resprate_missing_rate            406921 non-null  float64
#  64  o2sat_missing_rate               406921 non-null  float64
#  65  sbp_missing_rate                 406921 non-null  float64
#  66  dbp_missing_rate                 406921 non-null  float64
#  67  tachycardia_count                425087 non-null  int64
#  68  hypotension_count                425087 non-null  int64
#  69  hypoxia_count                    425087 non-null  int64
#  70  fever_count                      425087 non-null  int64
#  71  vital_pain_missing_count         425087 non-null  int64
#  72  diagnosis_count                  425087 non-null  int64
#  73  distinct_diagnosis_count         425087 non-null  int64
#  74  has_icd9                         425087 non-null  int64
#  75  has_icd10                        425087 non-null  int64
#  76  has_cardiovascular_dx            425087 non-null  int64
#  77  has_respiratory_dx               425087 non-null  int64
#  78  has_endocrine_dx                 425087 non-null  int64
#  79  has_renal_dx                     425087 non-null  int64
#  80  comorbidity_score                425087 non-null  int64
#  81  pyxis_med_count                  425087 non-null  int64
#  82  pyxis_distinct_med_count         425087 non-null  int64
#  83  pyxis_distinct_gsn_count         425087 non-null  int64
#  84  pyxis_missing_gsn_count          425087 non-null  int64
#  85  med_recon_count                  425087 non-null  int64
#  86  med_recon_distinct_med_count     425087 non-null  int64
#  87  med_recon_distinct_ndc_count     425087 non-null  int64
#  88  med_recon_missing_etccode_count  425087 non-null  int64
#  89  medication_intensity_score       425087 non-null  int64
#  90  risk_target                      425087 non-null  int64
#  91  updated_at                       425087 non-null  str
# dtypes: float64(41), int64(46), str(5)
# memory usage: 298.4 MB

# %%
#check nulls  , list all columns with nulls and the count of nulls in each column
null_counts = df.isnull().sum()
null_counts = null_counts[null_counts > 0]
print(null_counts)
# Out:
# triage_temperature          24032
# triage_heartrate            17130
# triage_resprate             20413
# triage_o2sat                20688
# triage_sbp                  18291
# triage_dbp                  19091
# acuity                       6987
# triage_shock_index          19130
# temperature_mean            26473
# temperature_min             26473
# temperature_max             26473
# hr_mean                     18487
# hr_min                      18487
# hr_max                      18487
# rr_mean                     18960
# rr_min                      18960
# rr_max                      18960
# spo2_mean                   29164
# spo2_min                    29164
# spo2_max                    29164
# sbp_mean                    18816
# sbp_min                     18816
# sbp_max                     18816
# dbp_mean                    18728
# dbp_min                     18728
# dbp_max                     18728
# shock_index                 19041
# shock_index_max             19041
# hr_first                    18487
# hr_last                     18487
# hr_slope                    98190
# sbp_first                   18816
# sbp_last                    18816
# bp_slope                    99340
# temperature_missing_rate    18166
# heartrate_missing_rate      18166
# resprate_missing_rate       18166
# o2sat_missing_rate          18166
# sbp_missing_rate            18166
# dbp_missing_rate            18166
# dtype: int64

# %%
#list categorical columns
categorical_cols = df.select_dtypes(include=['object']).columns
categorical_cols
# Out:
# /tmp/ipykernel_24613/4187924066.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = df.select_dtypes(include=['object']).columns
# Index(['gender', 'race', 'arrival_transport', 'disposition', 'updated_at'], dtype='str')

# %%
#print unique values in each categorical column
for col in categorical_cols:
    unique_values = df[col].unique()
    print(f"Unique values in column '{col}': {unique_values}")
    print("\n")
    print("-----------------------------------")
# Out:
# Unique values in column 'gender': <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str
#
#
# -----------------------------------
# Unique values in column 'race': <StringArray>
# [                                    'WHITE',
#                     'BLACK/AFRICAN AMERICAN',
#                                      'OTHER',
#             'HISPANIC/LATINO - PUERTO RICAN',
#                   'ASIAN - SOUTH EAST ASIAN',
#                       'ASIAN - ASIAN INDIAN',
#                'HISPANIC/LATINO - DOMINICAN',
#               'HISPANIC/LATINO - SALVADORAN',
#                     'BLACK/CARIBBEAN ISLAND',
#                                      'ASIAN',
#                  'HISPANIC/LATINO - MEXICAN',
#                     'WHITE - OTHER EUROPEAN',
#                   'WHITE - EASTERN EUROPEAN',
#                          'WHITE - BRAZILIAN',
#                                    'UNKNOWN',
#                         'HISPANIC OR LATINO',
#                             'SOUTH AMERICAN',
#                            'ASIAN - CHINESE',
#                         'BLACK/CAPE VERDEAN',
#                 'HISPANIC/LATINO - HONDURAN',
#               'HISPANIC/LATINO - GUATEMALAN',
#                              'BLACK/AFRICAN',
#                            'WHITE - RUSSIAN',
#  'NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER',
#                                 'PORTUGUESE',
#                'HISPANIC/LATINO - COLUMBIAN',
#                    'HISPANIC/LATINO - CUBAN',
#              'AMERICAN INDIAN/ALASKA NATIVE',
#                           'UNABLE TO OBTAIN',
#                 'PATIENT DECLINED TO ANSWER',
#                             'ASIAN - KOREAN',
#         'HISPANIC/LATINO - CENTRAL AMERICAN',
#                    'MULTIPLE RACE/ETHNICITY']
# Length: 33, dtype: str
#
#
# -----------------------------------
# Unique values in column 'arrival_transport': <StringArray>
# ['AMBULANCE', 'WALK IN', 'UNKNOWN', 'OTHER', 'HELICOPTER']
# Length: 5, dtype: str
#
#
# -----------------------------------
# Unique values in column 'disposition': <StringArray>
# [                   'ADMITTED',                      'ELOPED',
#                         'HOME',                    'TRANSFER',
#                        'OTHER',     'LEFT WITHOUT BEING SEEN',
#  'LEFT AGAINST MEDICAL ADVICE',                     'EXPIRED']
# Length: 8, dtype: str
#
#
# -----------------------------------
# Unique values in column 'updated_at': <StringArray>
# ['2026-04-28 23:17:54.396 +0300']
# Length: 1, dtype: str
#
#
# -----------------------------------
