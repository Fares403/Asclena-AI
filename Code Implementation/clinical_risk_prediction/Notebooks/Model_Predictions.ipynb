# %%
import polars as pl
df = pl.read_csv("/home/fares-ashraf/snap/dbeaver-ce/471/risk_predictions_202604292347.csv")

# %%
df.head()
# Out:
# shape: (5, 11)
# ┌───────────┬──────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ risk_pred ┆ stay_id  ┆ subject_i ┆ model_nam ┆ … ┆ risk_labe ┆ threshold ┆ top_featu ┆ created_a │
# │ iction_id ┆ ---      ┆ d         ┆ e         ┆   ┆ l         ┆ _used     ┆ res       ┆ t         │
# │ ---       ┆ i64      ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ i64       ┆          ┆ i64       ┆ str       ┆   ┆ str       ┆ f64       ┆ str       ┆ str       │
# ╞═══════════╪══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1         ┆ 30000012 ┆ 11714491  ┆ asclena_x ┆ … ┆ HIGH      ┆ 0.4       ┆ [{"featur ┆ 2026-04-2 │
# │           ┆          ┆           ┆ gboost_ri ┆   ┆           ┆           ┆ e": "vita ┆ 9 21:52:0 │
# │           ┆          ┆           ┆ sk        ┆   ┆           ┆           ┆ l_row_cou ┆ 8.521     │
# ...

# %%
df.select(pl.col("risk_label").value_counts())
# Out:
# shape: (3, 1)
# ┌────────────────────┐
# │ risk_label         │
# │ ---                │
# │ struct[2]          │
# ╞════════════════════╡
# │ {"HIGH",142242}    │
# │ {"MODERATE",97352} │
# │ {"LOW",185493}     │
# └────────────────────┘
